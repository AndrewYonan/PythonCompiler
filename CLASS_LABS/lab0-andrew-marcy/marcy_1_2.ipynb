# %%
x = 3+4
print(x)
# Out:
# 7

# %%
foo = 5
bar = 6
foobar = foo + bar
bozo = 7
squidward = 8
me = foo + bar + bozo + squidward

# %%
y=eval(input())
print(y)
# Out:
#  5
# 5

# %%
z=4+-3+3+-4
print(z)
# Out:
# 0

# %%
x1=5
print(print(x1))
# Out:
# 5
# None

# %%
print(eval(input()) + eval(input()))
# Out:
#  5
#  6
# 11

# %%
print(5+5+-eval(input()) +0 +0+0+0)
# Out:
#  5
# 5

# %%
x3 = 3 + -0
print(x3)
# Out:
# 3

# %%
x4 = 1000000000000000000000000000
print(x4 + 1)
# Out:
# 1000000000000000000000000001

# %%
print(x4+x4+x4)
# Was trying to find overflow, not sure how to make pyhton not convert to long int
# Out:
# 3000000000000000000000000000

# %%
x5 = 5
x6 = 10
print(x5+x6)
# Out:
# 15
